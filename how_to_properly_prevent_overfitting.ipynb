# %% [markdown]
# ## Imports

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler

# BLOB DATASET
from sklearn.datasets import make_blobs

# KERAS
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
# Out:
# 2023-08-15 14:49:42.796675: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # How to Properly Prevent Overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %% [markdown]
# ## Data - the `blobs` Dataset

# %% [markdown]
# ### Generating a Blobs Dataset
#
# First, let's generate some data using the [`make_blobs`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate 2000 samples with 10 features each; there should be 8 classes of blobs (`centers` argument) with `cluster_std` equal to 7.

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=2000, centers=8, n_features=10,random_state=0, cluster_std = 7)

# %% [markdown]
# ### Visualizing the Dataset
#
# All your samples have 10 features. Plot one of the dimensions against another.

# %%
import matplotlib.pyplot as plt

feature1 = 0 
feature2 = 1 

plt.scatter(X[:, feature1], X[:, feature2], c=y, cmap='viridis')
plt.xlabel(f"Feature {feature1}")
plt.ylabel(f"Feature {feature2}")
plt.title("Scatter Plot of Two Features")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Two Features')

# %% [markdown]
# ### Encoding your Categorical Target
#
# Use the 📚 [**to_categorical()**](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical) function to convert `y` to `y_cat`, which is the categorical representation of `y` with **One-Hot encoded** columns.

# %%
from keras.utils import to_categorical
import tensorflow as tf

y_cat = to_categorical(y, num_classes=None, dtype='float32')

y_cat = tf.keras.utils.to_categorical(y, num_classes=None, dtype='float32')

y_cat.shape
# Out:
# (2000, 8)

# %% [markdown]
# ## (1) Cross-Validation in Deep Learning
#
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a training set and a testing set at the beginning of the notebook. Then, we started to build different models which were trained on the training set and evaluated on the testing set.
#
# So, at the end of the day, we used the testing set every time we evaluated our models and different hyperparameters. This is normal: we always train on the training set and we evaluate on the testing set.
#
# However, we selected our "best model" based on the score of each model. In other words, we _used_ the test set to select our best model, which means there was ❗️ `data leakage` ❗️
#
# 🤔 **what should we do?**
#
# - A first good practice is to avoid using `random_state` or any deterministic separation between your training and testing sets. In that case, your testing set will change every time you re-run your notebook. This is far from being sufficient, though
# - To compare models properly, you have to run a cross-validation, a 10-fold split, for instance
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross -Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn, whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-validate a Neural Network**.

# %% [markdown]
# ### Designing a Neural Network
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - an **input layer** with 25 neurons, the `relu` activation function and the appropriate `input_dim`
# - a **hidden layer** with 10 neurons and the `relu` activation function.
# - a **predictive layer** that is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss
# - the *Adam* optimizer
# - the *accuracy* metric

# %%
from keras.models import Sequential
from keras.layers import Dense

def initialize_model(input_dim, num_classes):
    
    model = Sequential()
    
    model.add(Dense(25, input_dim=input_dim, activation='relu'))
    
    model.add(Dense(10, activation='relu'))
    
    model.add(Dense(num_classes, activation='softmax'))
  
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Cross-Validating the Neural Net
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the training data
# * 🧪 Evaluate your model on the testing data, and store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your training data before fitting the NN
# * 👌 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross-Validation, you are guided; just uncomment the following cell and follow the steps
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time, and we encourage you to do so whenever you run expensive computations

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense

num_classes = len(np.unique(y))

kf = KFold(n_splits=10)

results = []

for train_index, test_index in kf.split(X):
    
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    scaler = StandardScaler()
    
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    model = Sequential()
    
    model.add(Dense(25, input_dim=X_train_scaled.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    history = model.fit(X_train_scaled, to_categorical(y_train), epochs=150, verbose=0)
    
    accuracy = model.evaluate(X_test_scaled, to_categorical(y_test), verbose=0)
    results.append(accuracy[1]) 

accuracy = results
print(f'New mean accuracy: {np.mean(accuracy)*100:.2f}% (±{np.std(accuracy)*100:.2f})')

# %% [markdown]
# ### Performance of the Cross-Validated Network
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
accuracy = results
print(f'New mean accuracy: {np.mean(accuracy)*100:.2f}% (±{np.std(accuracy)*100:.2f})')

# %% [markdown]
# ### Remarks About the Computational Time
#
# - 🤯 You probably encountered one of the main drawbacks of using proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do **only one fold**
# - 👮🏻‍♀️ Remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique
# - 💼 In general, people split only once, as you did. Once they get to the end of their optimization, they launch a real cross-validation run at 6 PM, go home and get the final results on the next day

# %% [markdown]
# ### Holdout Method
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a training set and a testing set with a 70/30% training-to-test data ratio.
#
# Make sure to also scale the data after splitting!

# %%
x_train, x_test, y_train,y_test=train_test_split(X, y_cat ,test_size=0.3)

# %%
SScaler = StandardScaler()
SScaler.fit(x_train)

X_train_scaled = SScaler.transform(x_train)
X_test_scaled = SScaler.transform(x_test)

# %% [markdown]
# ## (2) How to Prevent a Neural Network from Overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 **Stop the learning process before overfitting**

# %% [markdown]
# #### Illustrating How a Neural Network Easily Overfits
#
# First things first, let's show that if we train the model for too long (= for too many epochs) it will overfit the training data and will not be good at predicting the testing data.
#
# **How can we do it without using the testing data, which is strictly forbidden?**
#
# You can use a fraction of the <font color=blue>training set</font> as a <font color=green>validation set</font>.
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/lectures/deep-learning/02/validation_set.png" width=450>
#
# With Keras, you don't have to re-use the `train_test_split` method from Scikit-Learn. Instead, you have two options:
#
# - `validation_split = 0.2` (for example)
#     - The model will take the last 20% of the observations in the training set and use this group as the validation holdout set
#     - If you want a random `train_val_split` within the training set, you can also add the argument `shuffle = True` in `model.fit()`
# - `validation_data = (X_val, y_val)` if you have access to a dataset that you want to use as the validation holdout set.
#
# 👉 Let's go with the first option and set `epochs = 500`.
#
# 👉 Store the performances of the model in a `history` variable.

# %%
# %%time

from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from sklearn.model_selection import train_test_split


model = initialize_model(10, 8)

history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=500,  verbose=1)

history
# Out:
# Epoch 1/500
# 35/35 [==============================] - 1s 5ms/step - loss: 2.1741 - accuracy: 0.1045 - val_loss: 2.0039 - val_accuracy: 0.1286
# Epoch 2/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.9557 - accuracy: 0.1384 - val_loss: 1.8701 - val_accuracy: 0.1893
# Epoch 3/500
# 35/35 [==============================] - 0s 2ms/step - loss: 1.8107 - accuracy: 0.2259 - val_loss: 1.7595 - val_accuracy: 0.2929
# Epoch 4/500
# 35/35 [==============================] - 0s 2ms/step - loss: 1.6759 - accuracy: 0.3580 - val_loss: 1.6450 - val_accuracy: 0.3929
# Epoch 5/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.5411 - accuracy: 0.4768 - val_loss: 1.5200 - val_accuracy: 0.4679
# Epoch 6/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.4070 - accuracy: 0.5545 - val_loss: 1.4029 - val_accuracy: 0.5357
# Epoch 7/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.2765 - accuracy: 0.6196 - val_loss: 1.2896 - val_accuracy: 0.5893
# Epoch 8/500
# 35/35 [==============================] - 0s 2ms/step - loss: 1.1561 - accuracy: 0.6562 - val_loss: 1.1846 - val_accuracy: 0.5964
# Epoch 9/500
# 35/35 [==============================] - 0s 2ms/step - loss: 1.0481 - accuracy: 0.6938 - val_loss: 1.0918 - val_accuracy: 0.6286
# Epoch 10/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.9573 - accuracy: 0.7152 - val_loss: 1.0104 - val_accuracy: 0.6679
# Epoch 11/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.8816 - accuracy: 0.7366 - val_loss: 0.9477 - val_accuracy: 0.6893
# Epoch 12/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.8223 - accuracy: 0.7491 - val_loss: 0.8965 - val_accuracy: 0.7036
# Epoch 13/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.7762 - accuracy: 0.7536 - val_loss: 0.8585 - val_accuracy: 0.7036
# Epoch 14/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.7424 - accuracy: 0.7509 - val_loss: 0.8301 - val_accuracy: 0.6893
# Epoch 15/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.7151 - accuracy: 0.7607 - val_loss: 0.8057 - val_accuracy: 0.7036
# Epoch 16/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6941 - accuracy: 0.7580 - val_loss: 0.7917 - val_accuracy: 0.7071
# Epoch 17/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6771 - accuracy: 0.7705 - val_loss: 0.7777 - val_accuracy: 0.7071
# Epoch 18/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6631 - accuracy: 0.7679 - val_loss: 0.7640 - val_accuracy: 0.7071
# Epoch 19/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6502 - accuracy: 0.7723 - val_loss: 0.7546 - val_accuracy: 0.7107
# Epoch 20/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.7768 - val_loss: 0.7459 - val_accuracy: 0.7036
# Epoch 21/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6317 - accuracy: 0.7804 - val_loss: 0.7396 - val_accuracy: 0.7179
# Epoch 22/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6207 - accuracy: 0.7866 - val_loss: 0.7307 - val_accuracy: 0.7179
# Epoch 23/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6152 - accuracy: 0.7839 - val_loss: 0.7252 - val_accuracy: 0.7250
# Epoch 24/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6075 - accuracy: 0.7902 - val_loss: 0.7194 - val_accuracy: 0.7321
# Epoch 25/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6024 - accuracy: 0.7946 - val_loss: 0.7167 - val_accuracy: 0.7393
# Epoch 26/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5946 - accuracy: 0.7902 - val_loss: 0.7101 - val_accuracy: 0.7429
# Epoch 27/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5925 - accuracy: 0.7955 - val_loss: 0.7099 - val_accuracy: 0.7429
# Epoch 28/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5845 - accuracy: 0.7955 - val_loss: 0.7050 - val_accuracy: 0.7429
# Epoch 29/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.7937 - val_loss: 0.7042 - val_accuracy: 0.7536
# Epoch 30/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5774 - accuracy: 0.8009 - val_loss: 0.6995 - val_accuracy: 0.7464
# Epoch 31/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5745 - accuracy: 0.7920 - val_loss: 0.6961 - val_accuracy: 0.7571
# Epoch 32/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5689 - accuracy: 0.7973 - val_loss: 0.6917 - val_accuracy: 0.7607
# Epoch 33/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5658 - accuracy: 0.8000 - val_loss: 0.6944 - val_accuracy: 0.7607
# Epoch 34/500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.5625 - accuracy: 0.8000 - val_loss: 0.6906 - val_accuracy: 0.7643
# Epoch 35/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5600 - accuracy: 0.8054 - val_loss: 0.6884 - val_accuracy: 0.7607
# Epoch 36/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5568 - accuracy: 0.8027 - val_loss: 0.6860 - val_accuracy: 0.7643
# Epoch 37/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5529 - accuracy: 0.8000 - val_loss: 0.6851 - val_accuracy: 0.7571
# Epoch 38/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.8036 - val_loss: 0.6817 - val_accuracy: 0.7643
# Epoch 39/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5462 - accuracy: 0.8027 - val_loss: 0.6826 - val_accuracy: 0.7607
# Epoch 40/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5451 - accuracy: 0.8000 - val_loss: 0.6833 - val_accuracy: 0.7571
# Epoch 41/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5440 - accuracy: 0.8062 - val_loss: 0.6821 - val_accuracy: 0.7607
# Epoch 42/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5408 - accuracy: 0.8071 - val_loss: 0.6778 - val_accuracy: 0.7679
# Epoch 43/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5393 - accuracy: 0.8062 - val_loss: 0.6809 - val_accuracy: 0.7536
# Epoch 44/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 0.8062 - val_loss: 0.6811 - val_accuracy: 0.7643
# Epoch 45/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5349 - accuracy: 0.8098 - val_loss: 0.6810 - val_accuracy: 0.7643
# Epoch 46/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5339 - accuracy: 0.8080 - val_loss: 0.6810 - val_accuracy: 0.7607
# Epoch 47/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5309 - accuracy: 0.8071 - val_loss: 0.6801 - val_accuracy: 0.7607
# Epoch 48/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5287 - accuracy: 0.8098 - val_loss: 0.6776 - val_accuracy: 0.7750
# Epoch 49/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.8125 - val_loss: 0.6784 - val_accuracy: 0.7571
# Epoch 50/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5266 - accuracy: 0.8080 - val_loss: 0.6780 - val_accuracy: 0.7643
# Epoch 51/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5254 - accuracy: 0.8062 - val_loss: 0.6803 - val_accuracy: 0.7679
# Epoch 52/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.8089 - val_loss: 0.6786 - val_accuracy: 0.7643
# Epoch 53/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5227 - accuracy: 0.8125 - val_loss: 0.6807 - val_accuracy: 0.7571
# Epoch 54/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.8089 - val_loss: 0.6794 - val_accuracy: 0.7714
# Epoch 55/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.8134 - val_loss: 0.6798 - val_accuracy: 0.7643
# Epoch 56/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5179 - accuracy: 0.8107 - val_loss: 0.6787 - val_accuracy: 0.7714
# Epoch 57/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5171 - accuracy: 0.8080 - val_loss: 0.6815 - val_accuracy: 0.7643
# Epoch 58/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5158 - accuracy: 0.8143 - val_loss: 0.6795 - val_accuracy: 0.7679
# Epoch 59/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5131 - accuracy: 0.8107 - val_loss: 0.6804 - val_accuracy: 0.7679
# Epoch 60/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5133 - accuracy: 0.8143 - val_loss: 0.6820 - val_accuracy: 0.7607
# Epoch 61/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5112 - accuracy: 0.8152 - val_loss: 0.6830 - val_accuracy: 0.7679
# Epoch 62/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5098 - accuracy: 0.8080 - val_loss: 0.6815 - val_accuracy: 0.7714
# Epoch 63/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5088 - accuracy: 0.8134 - val_loss: 0.6824 - val_accuracy: 0.7679
# Epoch 64/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5079 - accuracy: 0.8107 - val_loss: 0.6832 - val_accuracy: 0.7679
# Epoch 65/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5065 - accuracy: 0.8152 - val_loss: 0.6828 - val_accuracy: 0.7714
# Epoch 66/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5050 - accuracy: 0.8125 - val_loss: 0.6827 - val_accuracy: 0.7714
# Epoch 67/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5052 - accuracy: 0.8134 - val_loss: 0.6864 - val_accuracy: 0.7571
# Epoch 68/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5041 - accuracy: 0.8152 - val_loss: 0.6860 - val_accuracy: 0.7643
# Epoch 69/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5016 - accuracy: 0.8161 - val_loss: 0.6848 - val_accuracy: 0.7571
# Epoch 70/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5024 - accuracy: 0.8179 - val_loss: 0.6855 - val_accuracy: 0.7714
# Epoch 71/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4999 - accuracy: 0.8196 - val_loss: 0.6882 - val_accuracy: 0.7643
# Epoch 72/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5003 - accuracy: 0.8179 - val_loss: 0.6865 - val_accuracy: 0.7571
# Epoch 73/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4980 - accuracy: 0.8170 - val_loss: 0.6856 - val_accuracy: 0.7607
# Epoch 74/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4960 - accuracy: 0.8179 - val_loss: 0.6864 - val_accuracy: 0.7607
# Epoch 75/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.8188 - val_loss: 0.6908 - val_accuracy: 0.7571
# Epoch 76/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4952 - accuracy: 0.8170 - val_loss: 0.6872 - val_accuracy: 0.7536
# Epoch 77/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.8196 - val_loss: 0.6897 - val_accuracy: 0.7571
# Epoch 78/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4929 - accuracy: 0.8179 - val_loss: 0.6842 - val_accuracy: 0.7679
# Epoch 79/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4937 - accuracy: 0.8179 - val_loss: 0.6866 - val_accuracy: 0.7679
# Epoch 80/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4903 - accuracy: 0.8196 - val_loss: 0.6855 - val_accuracy: 0.7643
# Epoch 81/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4924 - accuracy: 0.8170 - val_loss: 0.6849 - val_accuracy: 0.7643
# Epoch 82/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4895 - accuracy: 0.8205 - val_loss: 0.6876 - val_accuracy: 0.7571
# Epoch 83/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4875 - accuracy: 0.8196 - val_loss: 0.6892 - val_accuracy: 0.7607
# Epoch 84/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4861 - accuracy: 0.8196 - val_loss: 0.6901 - val_accuracy: 0.7607
# Epoch 85/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4866 - accuracy: 0.8214 - val_loss: 0.6897 - val_accuracy: 0.7571
# Epoch 86/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4861 - accuracy: 0.8179 - val_loss: 0.6923 - val_accuracy: 0.7607
# Epoch 87/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4831 - accuracy: 0.8205 - val_loss: 0.6883 - val_accuracy: 0.7571
# Epoch 88/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4820 - accuracy: 0.8250 - val_loss: 0.6901 - val_accuracy: 0.7607
# Epoch 89/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4829 - accuracy: 0.8250 - val_loss: 0.6914 - val_accuracy: 0.7536
# Epoch 90/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4835 - accuracy: 0.8223 - val_loss: 0.6900 - val_accuracy: 0.7571
# Epoch 91/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4813 - accuracy: 0.8250 - val_loss: 0.6918 - val_accuracy: 0.7643
# Epoch 92/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4806 - accuracy: 0.8214 - val_loss: 0.6907 - val_accuracy: 0.7607
# Epoch 93/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4799 - accuracy: 0.8232 - val_loss: 0.6897 - val_accuracy: 0.7643
# Epoch 94/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.8250 - val_loss: 0.6935 - val_accuracy: 0.7536
# Epoch 95/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4772 - accuracy: 0.8250 - val_loss: 0.6929 - val_accuracy: 0.7536
# Epoch 96/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4761 - accuracy: 0.8268 - val_loss: 0.6953 - val_accuracy: 0.7607
# Epoch 97/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.8268 - val_loss: 0.6934 - val_accuracy: 0.7607
# Epoch 98/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.8286 - val_loss: 0.6931 - val_accuracy: 0.7500
# Epoch 99/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.8241 - val_loss: 0.6924 - val_accuracy: 0.7607
# Epoch 100/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4725 - accuracy: 0.8295 - val_loss: 0.6954 - val_accuracy: 0.7607
# Epoch 101/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4727 - accuracy: 0.8268 - val_loss: 0.6927 - val_accuracy: 0.7607
# Epoch 102/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.8259 - val_loss: 0.6921 - val_accuracy: 0.7607
# Epoch 103/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4703 - accuracy: 0.8286 - val_loss: 0.6938 - val_accuracy: 0.7607
# Epoch 104/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4703 - accuracy: 0.8259 - val_loss: 0.6970 - val_accuracy: 0.7571
# Epoch 105/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4704 - accuracy: 0.8268 - val_loss: 0.6967 - val_accuracy: 0.7643
# Epoch 106/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4682 - accuracy: 0.8304 - val_loss: 0.6952 - val_accuracy: 0.7607
# Epoch 107/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4672 - accuracy: 0.8259 - val_loss: 0.6964 - val_accuracy: 0.7679
# Epoch 108/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.8313 - val_loss: 0.6995 - val_accuracy: 0.7607
# Epoch 109/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.8304 - val_loss: 0.6982 - val_accuracy: 0.7571
# Epoch 110/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4656 - accuracy: 0.8304 - val_loss: 0.6967 - val_accuracy: 0.7607
# Epoch 111/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.8339 - val_loss: 0.7028 - val_accuracy: 0.7643
# Epoch 112/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4620 - accuracy: 0.8295 - val_loss: 0.6968 - val_accuracy: 0.7607
# Epoch 113/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4633 - accuracy: 0.8330 - val_loss: 0.6990 - val_accuracy: 0.7607
# Epoch 114/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0.8339 - val_loss: 0.6999 - val_accuracy: 0.7643
# Epoch 115/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.8313 - val_loss: 0.7020 - val_accuracy: 0.7536
# Epoch 116/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.8321 - val_loss: 0.6991 - val_accuracy: 0.7643
# Epoch 117/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.8321 - val_loss: 0.7001 - val_accuracy: 0.7571
# Epoch 118/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4571 - accuracy: 0.8357 - val_loss: 0.7014 - val_accuracy: 0.7607
# Epoch 119/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.8339 - val_loss: 0.7018 - val_accuracy: 0.7571
# Epoch 120/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4560 - accuracy: 0.8357 - val_loss: 0.7014 - val_accuracy: 0.7643
# Epoch 121/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.8366 - val_loss: 0.7043 - val_accuracy: 0.7643
# Epoch 122/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.8384 - val_loss: 0.7036 - val_accuracy: 0.7643
# Epoch 123/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4539 - accuracy: 0.8393 - val_loss: 0.7044 - val_accuracy: 0.7571
# Epoch 124/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.8384 - val_loss: 0.7083 - val_accuracy: 0.7607
# Epoch 125/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4552 - accuracy: 0.8357 - val_loss: 0.7076 - val_accuracy: 0.7571
# Epoch 126/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4510 - accuracy: 0.8357 - val_loss: 0.7085 - val_accuracy: 0.7607
# Epoch 127/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.8375 - val_loss: 0.7124 - val_accuracy: 0.7607
# Epoch 128/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.8357 - val_loss: 0.7123 - val_accuracy: 0.7571
# Epoch 129/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.8393 - val_loss: 0.7104 - val_accuracy: 0.7607
# Epoch 130/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.8375 - val_loss: 0.7082 - val_accuracy: 0.7607
# Epoch 131/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.8384 - val_loss: 0.7092 - val_accuracy: 0.7643
# Epoch 132/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4455 - accuracy: 0.8366 - val_loss: 0.7118 - val_accuracy: 0.7607
# Epoch 133/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4451 - accuracy: 0.8375 - val_loss: 0.7119 - val_accuracy: 0.7643
# Epoch 134/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8393 - val_loss: 0.7086 - val_accuracy: 0.7679
# Epoch 135/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.8411 - val_loss: 0.7135 - val_accuracy: 0.7643
# Epoch 136/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4437 - accuracy: 0.8348 - val_loss: 0.7145 - val_accuracy: 0.7607
# Epoch 137/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.8393 - val_loss: 0.7162 - val_accuracy: 0.7571
# Epoch 138/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.8429 - val_loss: 0.7134 - val_accuracy: 0.7571
# Epoch 139/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4397 - accuracy: 0.8402 - val_loss: 0.7159 - val_accuracy: 0.7714
# Epoch 140/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4394 - accuracy: 0.8393 - val_loss: 0.7211 - val_accuracy: 0.7643
# Epoch 141/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4392 - accuracy: 0.8420 - val_loss: 0.7170 - val_accuracy: 0.7679
# Epoch 142/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.8446 - val_loss: 0.7182 - val_accuracy: 0.7643
# Epoch 143/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4370 - accuracy: 0.8420 - val_loss: 0.7210 - val_accuracy: 0.7571
# Epoch 144/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4366 - accuracy: 0.8429 - val_loss: 0.7189 - val_accuracy: 0.7643
# Epoch 145/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4362 - accuracy: 0.8429 - val_loss: 0.7237 - val_accuracy: 0.7679
# Epoch 146/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.8420 - val_loss: 0.7265 - val_accuracy: 0.7607
# Epoch 147/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4340 - accuracy: 0.8455 - val_loss: 0.7211 - val_accuracy: 0.7750
# Epoch 148/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.8482 - val_loss: 0.7236 - val_accuracy: 0.7679
# Epoch 149/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.8438 - val_loss: 0.7252 - val_accuracy: 0.7500
# Epoch 150/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.8473 - val_loss: 0.7252 - val_accuracy: 0.7679
# Epoch 151/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8411 - val_loss: 0.7249 - val_accuracy: 0.7643
# Epoch 152/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8429 - val_loss: 0.7267 - val_accuracy: 0.7679
# Epoch 153/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4299 - accuracy: 0.8438 - val_loss: 0.7271 - val_accuracy: 0.7714
# Epoch 154/500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4283 - accuracy: 0.8464 - val_loss: 0.7283 - val_accuracy: 0.7679
# Epoch 155/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8455 - val_loss: 0.7281 - val_accuracy: 0.7607
# Epoch 156/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8482 - val_loss: 0.7309 - val_accuracy: 0.7714
# Epoch 157/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.8482 - val_loss: 0.7330 - val_accuracy: 0.7679
# Epoch 158/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8446 - val_loss: 0.7318 - val_accuracy: 0.7750
# Epoch 159/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.8438 - val_loss: 0.7339 - val_accuracy: 0.7750
# Epoch 160/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4244 - accuracy: 0.8491 - val_loss: 0.7321 - val_accuracy: 0.7750
# Epoch 161/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.8491 - val_loss: 0.7328 - val_accuracy: 0.7750
# Epoch 162/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8518 - val_loss: 0.7361 - val_accuracy: 0.7714
# Epoch 163/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.8500 - val_loss: 0.7388 - val_accuracy: 0.7571
# Epoch 164/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8500 - val_loss: 0.7352 - val_accuracy: 0.7750
# Epoch 165/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.8473 - val_loss: 0.7379 - val_accuracy: 0.7643
# Epoch 166/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4209 - accuracy: 0.8527 - val_loss: 0.7399 - val_accuracy: 0.7643
# Epoch 167/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4209 - accuracy: 0.8527 - val_loss: 0.7372 - val_accuracy: 0.7714
# Epoch 168/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4194 - accuracy: 0.8527 - val_loss: 0.7390 - val_accuracy: 0.7750
# Epoch 169/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4183 - accuracy: 0.8518 - val_loss: 0.7411 - val_accuracy: 0.7750
# Epoch 170/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8491 - val_loss: 0.7368 - val_accuracy: 0.7786
# Epoch 171/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4187 - accuracy: 0.8473 - val_loss: 0.7429 - val_accuracy: 0.7714
# Epoch 172/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4174 - accuracy: 0.8536 - val_loss: 0.7426 - val_accuracy: 0.7643
# Epoch 173/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.8571 - val_loss: 0.7447 - val_accuracy: 0.7679
# Epoch 174/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4188 - accuracy: 0.8464 - val_loss: 0.7414 - val_accuracy: 0.7750
# Epoch 175/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.8545 - val_loss: 0.7472 - val_accuracy: 0.7679
# Epoch 176/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8473 - val_loss: 0.7448 - val_accuracy: 0.7786
# Epoch 177/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8527 - val_loss: 0.7461 - val_accuracy: 0.7679
# Epoch 178/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4138 - accuracy: 0.8473 - val_loss: 0.7457 - val_accuracy: 0.7679
# Epoch 179/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.8562 - val_loss: 0.7483 - val_accuracy: 0.7714
# Epoch 180/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4114 - accuracy: 0.8562 - val_loss: 0.7460 - val_accuracy: 0.7750
# Epoch 181/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4115 - accuracy: 0.8545 - val_loss: 0.7503 - val_accuracy: 0.7786
# Epoch 182/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8509 - val_loss: 0.7515 - val_accuracy: 0.7750
# Epoch 183/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4110 - accuracy: 0.8554 - val_loss: 0.7512 - val_accuracy: 0.7750
# Epoch 184/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8509 - val_loss: 0.7509 - val_accuracy: 0.7821
# Epoch 185/500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4110 - accuracy: 0.8545 - val_loss: 0.7513 - val_accuracy: 0.7643
# Epoch 186/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8545 - val_loss: 0.7518 - val_accuracy: 0.7643
# Epoch 187/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4084 - accuracy: 0.8545 - val_loss: 0.7535 - val_accuracy: 0.7714
# Epoch 188/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4079 - accuracy: 0.8571 - val_loss: 0.7530 - val_accuracy: 0.7750
# Epoch 189/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4084 - accuracy: 0.8562 - val_loss: 0.7580 - val_accuracy: 0.7607
# Epoch 190/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8562 - val_loss: 0.7536 - val_accuracy: 0.7786
# Epoch 191/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.8562 - val_loss: 0.7570 - val_accuracy: 0.7714
# Epoch 192/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8527 - val_loss: 0.7613 - val_accuracy: 0.7750
# Epoch 193/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8545 - val_loss: 0.7557 - val_accuracy: 0.7714
# Epoch 194/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4050 - accuracy: 0.8536 - val_loss: 0.7575 - val_accuracy: 0.7821
# Epoch 195/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8527 - val_loss: 0.7600 - val_accuracy: 0.7786
# Epoch 196/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4030 - accuracy: 0.8571 - val_loss: 0.7618 - val_accuracy: 0.7750
# Epoch 197/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8554 - val_loss: 0.7633 - val_accuracy: 0.7750
# Epoch 198/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8571 - val_loss: 0.7672 - val_accuracy: 0.7643
# Epoch 199/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4029 - accuracy: 0.8527 - val_loss: 0.7604 - val_accuracy: 0.7714
# Epoch 200/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4029 - accuracy: 0.8491 - val_loss: 0.7646 - val_accuracy: 0.7714
# Epoch 201/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4005 - accuracy: 0.8598 - val_loss: 0.7661 - val_accuracy: 0.7679
# Epoch 202/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3998 - accuracy: 0.8571 - val_loss: 0.7673 - val_accuracy: 0.7786
# Epoch 203/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3996 - accuracy: 0.8562 - val_loss: 0.7681 - val_accuracy: 0.7750
# Epoch 204/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8562 - val_loss: 0.7677 - val_accuracy: 0.7786
# Epoch 205/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8589 - val_loss: 0.7678 - val_accuracy: 0.7786
# Epoch 206/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8545 - val_loss: 0.7699 - val_accuracy: 0.7750
# Epoch 207/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8562 - val_loss: 0.7696 - val_accuracy: 0.7786
# Epoch 208/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8518 - val_loss: 0.7714 - val_accuracy: 0.7786
# Epoch 209/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.8634 - val_loss: 0.7710 - val_accuracy: 0.7714
# Epoch 210/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8571 - val_loss: 0.7791 - val_accuracy: 0.7643
# Epoch 211/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8562 - val_loss: 0.7738 - val_accuracy: 0.7714
# Epoch 212/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8571 - val_loss: 0.7751 - val_accuracy: 0.7750
# Epoch 213/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3940 - accuracy: 0.8598 - val_loss: 0.7756 - val_accuracy: 0.7786
# Epoch 214/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8598 - val_loss: 0.7735 - val_accuracy: 0.7750
# Epoch 215/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8571 - val_loss: 0.7779 - val_accuracy: 0.7679
# Epoch 216/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8580 - val_loss: 0.7776 - val_accuracy: 0.7786
# Epoch 217/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.8616 - val_loss: 0.7787 - val_accuracy: 0.7714
# Epoch 218/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3921 - accuracy: 0.8545 - val_loss: 0.7765 - val_accuracy: 0.7714
# Epoch 219/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3931 - accuracy: 0.8598 - val_loss: 0.7803 - val_accuracy: 0.7786
# Epoch 220/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3930 - accuracy: 0.8580 - val_loss: 0.7847 - val_accuracy: 0.7714
# Epoch 221/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3896 - accuracy: 0.8580 - val_loss: 0.7782 - val_accuracy: 0.7821
# Epoch 222/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8589 - val_loss: 0.7801 - val_accuracy: 0.7714
# Epoch 223/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8580 - val_loss: 0.7864 - val_accuracy: 0.7714
# Epoch 224/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8598 - val_loss: 0.7809 - val_accuracy: 0.7786
# Epoch 225/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8589 - val_loss: 0.7813 - val_accuracy: 0.7714
# Epoch 226/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3865 - accuracy: 0.8607 - val_loss: 0.7866 - val_accuracy: 0.7679
# Epoch 227/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3870 - accuracy: 0.8598 - val_loss: 0.7854 - val_accuracy: 0.7750
# Epoch 228/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3867 - accuracy: 0.8616 - val_loss: 0.7859 - val_accuracy: 0.7750
# Epoch 229/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.8580 - val_loss: 0.7853 - val_accuracy: 0.7714
# Epoch 230/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3880 - accuracy: 0.8562 - val_loss: 0.7856 - val_accuracy: 0.7679
# Epoch 231/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3855 - accuracy: 0.8634 - val_loss: 0.7893 - val_accuracy: 0.7714
# Epoch 232/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3859 - accuracy: 0.8562 - val_loss: 0.7908 - val_accuracy: 0.7750
# Epoch 233/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3843 - accuracy: 0.8625 - val_loss: 0.7884 - val_accuracy: 0.7714
# Epoch 234/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3852 - accuracy: 0.8607 - val_loss: 0.7931 - val_accuracy: 0.7679
# Epoch 235/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.8634 - val_loss: 0.7933 - val_accuracy: 0.7679
# Epoch 236/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3855 - accuracy: 0.8580 - val_loss: 0.7896 - val_accuracy: 0.7786
# Epoch 237/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3843 - accuracy: 0.8616 - val_loss: 0.7918 - val_accuracy: 0.7679
# Epoch 238/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.8598 - val_loss: 0.7943 - val_accuracy: 0.7679
# Epoch 239/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3813 - accuracy: 0.8616 - val_loss: 0.7945 - val_accuracy: 0.7714
# Epoch 240/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3827 - accuracy: 0.8598 - val_loss: 0.7957 - val_accuracy: 0.7643
# Epoch 241/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8652 - val_loss: 0.7982 - val_accuracy: 0.7679
# Epoch 242/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3810 - accuracy: 0.
500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3073 - accuracy: 0.8893 - val_loss: 0.9987 - val_accuracy: 0.7536
# Epoch 489/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3064 - accuracy: 0.8911 - val_loss: 0.9940 - val_accuracy: 0.7500
# Epoch 490/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3035 - accuracy: 0.8911 - val_loss: 1.0007 - val_accuracy: 0.7464
# Epoch 491/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3041 - accuracy: 0.8911 - val_loss: 1.0038 - val_accuracy: 0.7393
# Epoch 492/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3033 - accuracy: 0.8938 - val_loss: 0.9989 - val_accuracy: 0.7464
# Epoch 493/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3061 - accuracy: 0.8955 - val_loss: 1.0032 - val_accuracy: 0.7571
# Epoch 494/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3040 - accuracy: 0.8884 - val_loss: 0.9998 - val_accuracy: 0.7429
# Epoch 495/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3032 - accuracy: 0.8955 - val_loss: 1.0124 - val_accuracy: 0.7393
# Epoch 496/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3050 - accuracy: 0.8866 - val_loss: 1.0103 - val_accuracy: 0.7357
# Epoch 497/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3078 - accuracy: 0.8884 - val_loss: 1.0136 - val_accuracy: 0.7357
# Epoch 498/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.8902 - val_loss: 1.0039 - val_accuracy: 0.7393
# Epoch 499/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3045 - accuracy: 0.8929 - val_loss: 1.0074 - val_accuracy: 0.7500
# Epoch 500/500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3014 - accuracy: 0.8893 - val_loss: 1.0083 - val_accuracy: 0.7393
# CPU times: user 33.4 s, sys: 8.19 s, total: 41.6 s
# Wall time: 27.1 s

# %% [markdown]
# #### Your Neural Network's Performance
#
# Evaluate the model on the testing set and print the accuracy.

# %%
loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
print(loss)
print(f"Testing accuracy: {accuracy*100:.2f}%")
# Out:
# 1.2702614068984985
# Testing accuracy: 69.83%

# %% [markdown]
# #### Learnings About Number of Epochs
#
# Plot the history of the model with the `plot_loss_accuracy()` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))

    # --- LOSS --- 

    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])

    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')

    ax[0].set_ylim((0,3))

    ax[0].legend(['Train', 'Test'], loc='best')

    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)

    # --- ACCURACY

    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])

    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')

    ax[1].legend(['Train', 'Test'], loc='best')

    ax[1].set_ylim((0,1))

    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)

    if title:
        fig.suptitle(title)

# %%
plot_loss_accuracy(history)

# %% [markdown]
# 👩🏻‍🏫 We clearly see that **the number of epochs we choose has a strong influence on the final results**:
#
# **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
# - The algorithm is not optimal as its Loss Function has **not converged yet**
# - It hasn't learned enough from the training data
#
# **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
# - Our Neural Network has **learned too much** from the training data, including its noisy information
# - the algorithm **does not generalize well** on test data
#
# 🚦 Basically, what we want to do is stop the algorithm **when the test loss is minimal** (or when the testing metrics are maximal)

# %% [markdown]
# #### Early Stopping
#
# 🧑🏻‍🏫 Let's introduce the **Early Stopping** criterion.
#
# The Early Stopping criterion is a way to **automatically stop the training of the algorithm** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ **How does it work?**
#
# The model will pay attention to the **<font color=green>loss of the validation set</font>**. If <font color=green>it</font> starts increasing again 📈 while the <font color=blue>loss of the training set</font> keeps decreasing 📉, it is a good sign that the model is overfitting and the training should be stopped!
#
#
# <img src="validation_set.png" alt="Validation set" width=450/>

# %% [markdown]
# ##### Observing the Early Stopping Criterion
#
# Run the following code and plot the history.

# %%
# %%time

es = EarlyStopping()

model = initialize_model(10, 8)

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16, 
    verbose = 1, 
    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 4ms/step - loss: 2.0701 - accuracy: 0.1553 - val_loss: 2.0028 - val_accuracy: 0.1876
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9137 - accuracy: 0.2707 - val_loss: 1.8511 - val_accuracy: 0.3135
# CPU times: user 860 ms, sys: 101 ms, total: 960 ms
# Wall time: 840 ms

# %% [markdown]
# ##### Evaluate the ES Model
#
# _(also look at the historical losses)_

# %%
plot_loss_accuracy(history)

# %% [markdown]
# ❗ **The problem with strict Early Stopping** ❗
#
# The problem with this type of approach is that as soon as the loss of the validation set increases, the model stops. However, as a Neural Network's convergence is stochastic, the loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a `patience` keyword that defines how many **consecutive epochs without any loss decrease** are allowed in the validation set before we stop the training procedure.
#
# Use the `EarlyStopping` criterion with a patience term of 30 epochs, plot the results, and print the accuracy on the testing set

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)

history = model.fit(x_train, y_train, epochs=100, validation_data=(X_train_scaled, y_train), callbacks=[callback])

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = model.evaluate(x_test, y_test)[1]
print(f"Testing accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/100
# 44/44 [==============================] - 0s 3ms/step - loss: 1.7616 - accuracy: 0.3900 - val_loss: 1.8086 - val_accuracy: 0.4736
# Epoch 2/100
# 44/44 [==============================] - 0s 2ms/step - loss: 1.2791 - accuracy: 0.5529 - val_loss: 1.7696 - val_accuracy: 0.5750
# Epoch 3/100
# 44/44 [==============================] - 0s 2ms/step - loss: 1.0589 - accuracy: 0.6293 - val_loss: 1.7144 - val_accuracy: 0.6307
# Epoch 4/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.9300 - accuracy: 0.6736 - val_loss: 1.6722 - val_accuracy: 0.6514
# Epoch 5/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.8429 - accuracy: 0.7043 - val_loss: 1.6340 - val_accuracy: 0.6793
# Epoch 6/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.7879 - accuracy: 0.7314 - val_loss: 1.6104 - val_accuracy: 0.6857
# Epoch 7/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.7449 - accuracy: 0.7393 - val_loss: 1.5923 - val_accuracy: 0.6950
# Epoch 8/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.7122 - accuracy: 0.7493 - val_loss: 1.5758 - val_accuracy: 0.7143
# Epoch 9/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.7636 - val_loss: 1.5596 - val_accuracy: 0.7186
# Epoch 10/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6687 - accuracy: 0.7614 - val_loss: 1.5480 - val_accuracy: 0.7164
# Epoch 11/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6551 - accuracy: 0.7657 - val_loss: 1.5394 - val_accuracy: 0.7186
# Epoch 12/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.6416 - accuracy: 0.7750 - val_loss: 1.5303 - val_accuracy: 0.7236
# Epoch 13/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.7700 - val_loss: 1.5240 - val_accuracy: 0.7207
# Epoch 14/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6241 - accuracy: 0.7743 - val_loss: 1.5191 - val_accuracy: 0.7221
# Epoch 15/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6181 - accuracy: 0.7771 - val_loss: 1.5128 - val_accuracy: 0.7264
# Epoch 16/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6067 - accuracy: 0.7807 - val_loss: 1.5090 - val_accuracy: 0.7243
# Epoch 17/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.7836 - val_loss: 1.5026 - val_accuracy: 0.7286
# Epoch 18/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.7843 - val_loss: 1.4980 - val_accuracy: 0.7279
# Epoch 19/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5874 - accuracy: 0.7893 - val_loss: 1.4955 - val_accuracy: 0.7364
# Epoch 20/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5781 - accuracy: 0.7936 - val_loss: 1.4936 - val_accuracy: 0.7271
# Epoch 21/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5758 - accuracy: 0.7886 - val_loss: 1.4886 - val_accuracy: 0.7314
# Epoch 22/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5682 - accuracy: 0.8029 - val_loss: 1.4847 - val_accuracy: 0.7314
# Epoch 23/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7964 - val_loss: 1.4831 - val_accuracy: 0.7371
# Epoch 24/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5589 - accuracy: 0.8000 - val_loss: 1.4807 - val_accuracy: 0.7243
# Epoch 25/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5554 - accuracy: 0.7986 - val_loss: 1.4792 - val_accuracy: 0.7350
# Epoch 26/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.8021 - val_loss: 1.4760 - val_accuracy: 0.7221
# Epoch 27/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5501 - accuracy: 0.8000 - val_loss: 1.4754 - val_accuracy: 0.7243
# Epoch 28/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7986 - val_loss: 1.4729 - val_accuracy: 0.7150
# Epoch 29/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5424 - accuracy: 0.8043 - val_loss: 1.4735 - val_accuracy: 0.7157
# Epoch 30/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 0.7993 - val_loss: 1.4741 - val_accuracy: 0.7100
# Epoch 31/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.8021 - val_loss: 1.4731 - val_accuracy: 0.7100
# Epoch 32/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5317 - accuracy: 0.8043 - val_loss: 1.4700 - val_accuracy: 0.7143
# Epoch 33/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.8014 - val_loss: 1.4666 - val_accuracy: 0.7064
# Epoch 34/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5233 - accuracy: 0.8086 - val_loss: 1.4674 - val_accuracy: 0.7079
# Epoch 35/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5251 - accuracy: 0.8057 - val_loss: 1.4695 - val_accuracy: 0.6929
# Epoch 36/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5200 - accuracy: 0.8043 - val_loss: 1.4672 - val_accuracy: 0.6964
# Epoch 37/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5171 - accuracy: 0.8036 - val_loss: 1.4634 - val_accuracy: 0.6893
# Epoch 38/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5158 - accuracy: 0.8036 - val_loss: 1.4641 - val_accuracy: 0.6900
# Epoch 39/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5114 - accuracy: 0.8079 - val_loss: 1.4620 - val_accuracy: 0.6857
# Epoch 40/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.8079 - val_loss: 1.4606 - val_accuracy: 0.6829
# Epoch 41/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.8093 - val_loss: 1.4618 - val_accuracy: 0.6757
# Epoch 42/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.8079 - val_loss: 1.4632 - val_accuracy: 0.6693
# Epoch 43/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.8071 - val_loss: 1.4602 - val_accuracy: 0.6700
# Epoch 44/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4988 - accuracy: 0.8121 - val_loss: 1.4593 - val_accuracy: 0.6629
# Epoch 45/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4976 - accuracy: 0.8107 - val_loss: 1.4544 - val_accuracy: 0.6629
# Epoch 46/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.8136 - val_loss: 1.4581 - val_accuracy: 0.6600
# Epoch 47/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4949 - accuracy: 0.8100 - val_loss: 1.4581 - val_accuracy: 0.6479
# Epoch 48/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4915 - accuracy: 0.8179 - val_loss: 1.4516 - val_accuracy: 0.6543
# Epoch 49/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.8107 - val_loss: 1.4500 - val_accuracy: 0.6600
# Epoch 50/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.8143 - val_loss: 1.4529 - val_accuracy: 0.6500
# Epoch 51/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4889 - accuracy: 0.8157 - val_loss: 1.4517 - val_accuracy: 0.6386
# Epoch 52/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4818 - accuracy: 0.8214 - val_loss: 1.4542 - val_accuracy: 0.6279
# Epoch 53/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.8200 - val_loss: 1.4437 - val_accuracy: 0.6464
# Epoch 54/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.8171 - val_loss: 1.4523 - val_accuracy: 0.6229
# Epoch 55/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4812 - accuracy: 0.8200 - val_loss: 1.4471 - val_accuracy: 0.6257
# Epoch 56/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4794 - accuracy: 0.8171 - val_loss: 1.4431 - val_accuracy: 0.6243
# Epoch 57/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4771 - accuracy: 0.8143 - val_loss: 1.4442 - val_accuracy: 0.6336
# Epoch 58/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.8221 - val_loss: 1.4507 - val_accuracy: 0.5979
# Epoch 59/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.8107 - val_loss: 1.4479 - val_accuracy: 0.6007
# Epoch 60/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.8279 - val_loss: 1.4494 - val_accuracy: 0.5964
# Epoch 61/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.8207 - val_loss: 1.4405 - val_accuracy: 0.6114
# Epoch 62/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.8221 - val_loss: 1.4485 - val_accuracy: 0.5843
# Epoch 63/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.8243 - val_loss: 1.4436 - val_accuracy: 0.5936
# Epoch 64/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.8229 - val_loss: 1.4443 - val_accuracy: 0.5971
# Epoch 65/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4656 - accuracy: 0.8229 - val_loss: 1.4453 - val_accuracy: 0.5907
# Epoch 66/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.8214 - val_loss: 1.4456 - val_accuracy: 0.5871
# Epoch 67/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.8243 - val_loss: 1.4470 - val_accuracy: 0.5771
# Epoch 68/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.8307 - val_loss: 1.4395 - val_accuracy: 0.5850
# Epoch 69/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.8214 - val_loss: 1.4435 - val_accuracy: 0.5736
# Epoch 70/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4588 - accuracy: 0.8264 - val_loss: 1.4456 - val_accuracy: 0.5764
# Epoch 71/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4588 - accuracy: 0.8307 - val_loss: 1.4436 - val_accuracy: 0.5614
# Epoch 72/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.8300 - val_loss: 1.4448 - val_accuracy: 0.5650
# Epoch 73/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.8300 - val_loss: 1.4394 - val_accuracy: 0.5721
# Epoch 74/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.8314 - val_loss: 1.4469 - val_accuracy: 0.5564
# Epoch 75/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.8279 - val_loss: 1.4486 - val_accuracy: 0.5514
# Epoch 76/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4506 - accuracy: 0.8264 - val_loss: 1.4385 - val_accuracy: 0.5671
# Epoch 77/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.8336 - val_loss: 1.4467 - val_accuracy: 0.5486
# Epoch 78/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8314 - val_loss: 1.4519 - val_accuracy: 0.5386
# Epoch 79/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.8314 - val_loss: 1.4438 - val_accuracy: 0.5529
# Epoch 80/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.8293 - val_loss: 1.4386 - val_accuracy: 0.5586
# Epoch 81/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.8279 - val_loss: 1.4427 - val_accuracy: 0.5493
# Epoch 82/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.8329 - val_loss: 1.4456 - val_accuracy: 0.5379
# Epoch 83/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4438 - accuracy: 0.8329 - val_loss: 1.4423 - val_accuracy: 0.5407
# Epoch 84/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.8321 - val_loss: 1.4424 - val_accuracy: 0.5407
# Epoch 85/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.8343 - val_loss: 1.4450 - val_accuracy: 0.5407
# Epoch 86/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.8321 - val_loss: 1.4509 - val_accuracy: 0.5250
# Epoch 87/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.8357 - val_loss: 1.4508 - val_accuracy: 0.5257
# Epoch 88/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.8379 - val_loss: 1.4549 - val_accuracy: 0.5243
# Epoch 89/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.8314 - val_loss: 1.4516 - val_accuracy: 0.5229
# Epoch 90/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.8379 - val_loss: 1.4481 - val_accuracy: 0.5250
# Epoch 91/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.8371 - val_loss: 1.4447 - val_accuracy: 0.5343
# Epoch 92/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.8357 - val_loss: 1.4496 - val_accuracy: 0.5250
# Epoch 93/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.8386 - val_loss: 1.4531 - val_accuracy: 0.5193
# Epoch 94/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.8350 - val_loss: 1.4510 - val_accuracy: 0.5193
# Epoch 95/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.8379 - val_loss: 1.4491 - val_accuracy: 0.5193
# Epoch 96/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8371 - val_loss: 1.4528 - val_accuracy: 0.5143
# Epoch 97/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.8386 - val_loss: 1.4587 - val_accuracy: 0.5050
# Epoch 98/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.8336 - val_loss: 1.4606 - val_accuracy: 0.5014
# Epoch 99/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.8400 - val_loss: 1.4505 - val_accuracy: 0.5107
# Epoch 100/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4244 - accuracy: 0.8393 - val_loss: 1.4571 - val_accuracy: 0.5014
# 19/19 [==============================] - 0s 808us/step - loss: 0.9078 - accuracy: 0.7017
# Testing accuracy: 70.17%

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# - 📉 The model continues to converge even though its Loss Function had some consecutive loss increases/decreases w.r.t. to the number of epochs
# - 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand, and there is no general rule of thumb
# - 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     - 🤞 your Neural Network should theoretically still stop training before the end (not always the case if your number of epochs is too low)
#     - ❗️ your validation loss will increase again after reaching a minimum value, but ideally, you want it to be as low as possible; the validation loss potentially reaches a minimum for certain weights at a certain epoch
#         - 🤔 How to find these weights?
#
# 📚 The `EarlyStopping` criterion enables you to:
# - stop the convergence
# - restore the best weights of the NN when it had the lowest error level (or the best score) on the validation set, thanks to `restore_best_weights = True` (set to `False` by default)

# %% [markdown]
# ##### Restoring the Best Weights of a Model
#
# - Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# - Plot the loss and accuracy
# - Print the accuracy on the testing set

# %%
# YOUR CODE HERE

# %% [markdown]
# 🥡 **Takeaways from the Early Stopping criterion:**
#
# - You can look at the 📚 [**Early Stopping documentation**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
# - You no longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch Size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# #### Playing with the Batch Size
#
# Let's run the previous model with **different batch sizes** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL
es = EarlyStopping(patience=20, restore_best_weights=True)

for batch_size in [1, 4, 32]:
    
    model = initialize_model()

    history = model.fit(
        X_train_scaled,
        y_train,
        validation_split = 0.3,
        epochs = 500,
        batch_size = batch_size, 
        verbose = 0, 
        callbacks = [es]
    )

    results = model.evaluate(X_test_scaled, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is of {results[1]:.2f}')

# %% [markdown]
# #### ❓Question: Impact of the Batch Size on the Convergence of a Neural Network
#
# Look at the oscillations of the accuracy and the loss according to the batch size number.
#
# Is this coherent with what we saw when playing with the TensorFlow Playground?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### ❓Question: Number of Parameter Updates
#
# How many weight optimizations are done within one epoch (considering the number of observations and the batch size)? Does one epoch have more weight updates with a large or with a small batch size?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### Explanations
#
# Copy and paste this code into a new cell, run it, and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(
#     X_train_scaled,
#     y_train,
#     validation_split = 0.3,
#     epochs = epochs,
#     batch_size = batch_size,
#     verbose = 1
# )
# ```
#
#
# <u><b>Number of parameter updates:</b></u>
#
# - There are 1400 rows in the training set:
#     - $ 70 \% \times 1400 = 980 $ rows are used as the training set within the training set
#     - $ 30 \% \times 1400 = 420 $ rows are used as the validation set
# - For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
# - Without the Early Stopping Criterion, we will have _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations overall
#
# <u><b>Impact of the batch size:</b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
# $ \implies $ Parameters will be updated more frequently
# $ \implies $ We may need fewer epochs
#
# _(but we also don't care too much about the number of epochs if we use an Early Stopping Criterion with a patience term anyway)_

# %%
batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(
    X_train_scaled, 
    y_train,
    validation_split = 0.3,
    epochs = epochs,
    batch_size = batch_size, 
    verbose = 1
)

# %% [markdown]
# ### (2.3) Regularization
#
# ❗️**Neural Networks with complex architectures can quickly lead to overfitting** (_too many layers and/or neurons_)❗️
#
# 🔥 But since Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2, or L1-L2 penalties!
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons; as in Machine Learning, these penalties are called **`Regularizers`**.
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">See `tf.keras.regularizers`</a>

# %% [markdown]
# #### Observing Overfitting Before Regularizing
#
# First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. To that purpose, let's not use any Early Stopping criterion.
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training 
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
    batch_size = 16, 
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose = 0)
results_test = model.evaluate(X_test_scaled, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)

# %% [markdown]
# ☝️ In our "over-parameterized network", some neurons became **too specific for the given training data**, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting!

# %% [markdown]
# #### Studying the Impact of Regularization on the Neural Network
#
# Change the previous code to integrate an L2 or L1 regularizer into your Dense Layers.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (2.4) Dropout Layers

# %% [markdown]
# #### Introduction to Dropout Layers
#
# The role of a Dropout Layer is to randomly cancel the output of some neurons during the training phase, it prevents the network from getting too specific for the input data.
#
# Dropout Layers
# - ensure that no neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled
# - force the information of an input to be spread across multiple neurons instead of only one specific neuron
# - are super straightforward to code 👌
#   - but what is going on _under the hood_? 👩🏻‍🏫

# %% [markdown]
# #### Optional Reading
#
# <details>
#     <summary>Click here for further explanations about Dropout Layers</summary>
#
# 🤔 Remember what we said about neurons becoming **too specific**?
#
# **`BEGIN_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# ---
#
# ⚽️  **A Football Analogy:**
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench. Why?
# - The coach may want to substitute injured or tired players during the game
# - The team may be
#     - losing the game and willing to substitute a midfielder with a more **versatile player** who can be more offensive (= **mix of** midfielder/attacker roles)
#     - winning the game and would like to secure the result by replacing a midfielder with a more **versatile player** who can be more defensive (= **mix of** midfielder/defense roles)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, where it would be advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing.**
#
# 🧑🏻‍🏫 How do Dropout Layers work?
#
# 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the **selected neurons** will have their weights **temporarily set to 0** , which has the following consequences:
# 1. A neuron computed at layer $k + 1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k + 1$
# 2. Once a batch of data points has been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer have been optimized/updated (**backward propagation** with the **Adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#    - 80% of the weights; the ones that were updated
#    - 20% of the weights; the ones that were previously ignored and had their values **temporarily** set to 0
#
# Based on these weights, we will go through this Dropout Layer again, which is going to temporarily ignore another 20% of the weights of a given layer. Be careful, the selection of this 20% is random, so the weights that will be ignored this time won't necessarily be the same as before!
#
# 👉 Think about the **Dropout rate** as a **sampling with replacement**
#
# 👉 By **randomly shutting down** different neurons at different epochs, we force the data points to be **analyzed by different neurons**. At the end of the day, these neurons will become **more versatile** instead of over-specializing!
#
# ---
#
# **`END_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
# </details>

# %% [markdown]
# #### Studying the Impact of Dropout Layers on the Neural Network
#
# Include some Dropout layers in the architecture of your original model _(don't add regularizers here)_.
#
# What can you observe regarding the convergence of your model? What about its ability to generalize?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## (3) Conclusions
#
# - ❗️ If you train a Neural Network too much (too many layers, too many neurons, and/or too many epochs), it will overfit very quickly
# - 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization, and Dropout Layers
# - ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where your model would underfit the dataset!
# - 🆗 You could potentially look at the batch size but we usually use 16 or 32; and as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="500">

# %% [markdown]
# ## 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
